# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split # for splitting the data into training and testing sets
from sklearn.linear_model import LinearRegression, Ridge # models we are going to use
from sklearn.metrics import r2_score # for comparing the predicted and test values
import seaborn as sns;

# %% [markdown]
# ### WITH THE FIRST DATASET

# %%
df1 = pd.read_csv("chipVariantCalling_run1.tsv", sep = '\t')
df1.head()
# Out:
#     d.barcode    DP  VD      AF    HIAF    IMPACT SYMBOL              loci  \
# 0  4010289633  7281  26  0.0036  0.0033  MODERATE   GNB1  chr1:1747196_T/C
# 1  4010289633  7281  26  0.0036  0.0033  MODERATE   GNB1  chr1:1747196_T/C
# 2  4010289633  7281  26  0.0036  0.0033  MODERATE   GNB1  chr1:1747196_T/C
# 3  4010289633  7281  26  0.0036  0.0033  MODERATE   GNB1  chr1:1747196_T/C
# 4  4010289633  7282  29  0.0040  0.0036  MODERATE   GNB1  chr1:1747250_T/C
#
#   sampleTimePt gender    MSID BIAS    REFBIAS VARBIAS  QUAL  ODDRATIO  \
# 0     Baseline   Male  MS2083  2:2  3644:3596   12:14  34.0  1.182210
# 1     Baseline   Male  MS2083  2:2  3644:3596   12:14  34.0  1.182210
# 2     Baseline   Male  MS2083  2:2  3644:3596   12:14  34.0  1.182210
# 3     Baseline   Male  MS2083  2:2  3644:3596   12:14  34.0  1.182210
# 4     Baseline   Male  MS2083  2:2  3639:3606   15:14  32.7  1.061729
#
#   chipOrControl
# 0          CHIP
# 1          CHIP
# 2          CHIP
# 3          CHIP
# 4          CHIP

# %%
#drop unnecessary columns
df1 = df1[df1.chipOrControl != 'Blank']
df1 = df1[df1.chipOrControl != 'Unknown']
df1 = df1.drop_duplicates()
df1 = df1.dropna(subset=['chipOrControl'])
df1.drop(['d.barcode', 'IMPACT', 'gender'], axis=1, inplace=True)

# %%
df1 = df1.replace({'chipOrControl': {'CHIP': 1, 'Control': 0}})

df1.head()
# Out:
#       DP  VD      AF    HIAF SYMBOL                loci sampleTimePt    MSID  \
# 0   7281  26  0.0036  0.0033   GNB1    chr1:1747196_T/C     Baseline  MS2083
# 4   7282  29  0.0040  0.0036   GNB1    chr1:1747250_T/C     Baseline  MS2083
# 8   7282  24  0.0033  0.0033   GNB1    chr1:1747256_T/C     Baseline  MS2083
# 12   178   2  0.0112  0.0120   NRAS  chr1:115256571_T/C     Baseline  MS2083
# 13  1773   6  0.0034  0.0035   NRAS  chr1:115258674_T/C     Baseline  MS2083
#
#    BIAS    REFBIAS VARBIAS  QUAL  ODDRATIO  chipOrControl
# 0   2:2  3644:3596   12:14  34.0  1.182210              1
# 4   2:2  3639:3606   15:14  32.7  1.061729              1
# 8   2:2  3626:3607   12:12  34.9  1.005270              1
# 12  2:2      88:88     1:1  37.0  1.000000              1
# 13  2:2    889:874     3:3  37.0  1.017150              1

# %%
#converting reference bias and variable bias to float types
def ratio_to_int(string):
    a, b = string.split(":")
    if int(b) == 0:
        return 0
    else:
        return int(a) / int(b)

refbias = []
varbias = []

for ratio in df1.REFBIAS.array:
    refbias.append(ratio_to_int(str(ratio))) 

for ratio in df1.VARBIAS.array:
    varbias.append(ratio_to_int(str(ratio))) 
    
refbias = pd.Series(refbias)
varbias = pd.Series(varbias)

df1['REFBIAS'] = refbias.values
df1['VARBIAS'] = varbias.values

# %%
df1
# Out:
#           DP  VD      AF    HIAF SYMBOL                loci sampleTimePt  \
# 0       7281  26  0.0036  0.0033   GNB1    chr1:1747196_T/C     Baseline
# 4       7282  29  0.0040  0.0036   GNB1    chr1:1747250_T/C     Baseline
# 8       7282  24  0.0033  0.0033   GNB1    chr1:1747256_T/C     Baseline
# 12       178   2  0.0112  0.0120   NRAS  chr1:115256571_T/C     Baseline
# 13      1773   6  0.0034  0.0035   NRAS  chr1:115258674_T/C     Baseline
# ...      ...  ..     ...     ...    ...                 ...          ...
# 536725   711   2  0.0028  0.0028  BRCC3  chrX:154305513_C/T           Y3
# 536726   711   2  0.0028  0.0029  BRCC3  chrX:154305518_T/C           Y3
# 536733   711   2  0.0028  0.0029  BRCC3  chrX:154305518_T/C           Y3
# 536734   711   2  0.0028  0.0029  BRCC3  chrX:154305533_A/T           Y3
# 536741   711   2  0.0028  0.0028  BRCC3  chrX:154305535_C/G           Y3
#
#           MSID BIAS   REFBIAS   VARBIAS  QUAL  ODDRATIO  chipOrControl
# 0       MS2083  2:2  1.013348  0.857143  34.0  1.182210              1
# 4       MS2083  2:2  1.009151  1.071429  32.7  1.061729              1
# 8       MS2083  2:2  1.005268  1.000000  34.9  1.005270              1
# 12      MS2083  2:2  1.000000  1.000000  37.0  1.000000              1
# 13      MS2083  2:2  1.017162  1.000000  37.0  1.017150              1
# ...        ...  ...       ...       ...   ...       ...            ...
# 536725  MS6625  2:2  1.008499  1.000000  31.0  1.008490              0
# 536726  MS6625  2:2  1.005666  1.000000  37.0  1.005660              0
# 536733  MS6625  2:2  1.005666  1.000000  37.0  1.005660              0
# 536734  MS6625  2:2  1.008499  1.000000  37.0  1.008490              0
# 536741  MS6625  2:2  1.008499  1.000000  25.0  1.008490              0
#
# [121936 rows x 14 columns]

# %% [markdown]
# Twp different dataframes:
#
# `actual_chip` - contains all the values with `AF`>= 0.02 (by contemporary definition) and are classified as CHIP
#
# `false_control` - contains all the values with `AF`>= 0.02 but are classified as Control

# %%
allele_fq = df1[df1["AF"] >= 0.02]
actual_chip = allele_fq[allele_fq["chipOrControl"] == 1]
false_control = allele_fq[allele_fq["chipOrControl"] == 0]
actual_chip
# Out:
#             DP      VD      AF    HIAF  SYMBOL                loci  \
# 276         80       2  0.0250  0.0260  DNMT3A   chr2:25467154_G/A
# 716       4201    2113  0.5030  0.5025    TET2  chr4:106155620_C/A
# 1332         2       2  1.0000  1.0000    TET2  chr4:106157527_C/T
# 1444        50       3  0.0600  0.0435    TET2  chr4:106158252_G/T
# 1452        51       2  0.0392  0.0417    TET2  chr4:106158331_A/G
# ...        ...     ...     ...     ...     ...                 ...
# 526423   96274   47654  0.4950  0.4966   SNX18   chr5:53815495_A/C
# 526738    1681    1668  0.9923  0.9958    TP53   chr17:7579472_G/C
# 526776      53       2  0.0377  0.0385   SRSF2  chr17:74733034_T/C
# 526835   25218   24992  0.9910  0.9959   ASXL1  chr20:31022959_T/C
# 526929  192892  190717  0.9887  0.9949    LIPI  chr21:15481365_G/T
#
#        sampleTimePt     MSID BIAS   REFBIAS   VARBIAS  QUAL  ODDRATIO  \
# 276        Baseline   MS2083  2:2  1.166667  1.000000  37.0  1.164410
# 716        Baseline   MS2083  2:2  1.010628  1.018147  35.8  1.007435
# 1332       Baseline   MS2083  0:2  0.000000  1.000000  31.0  0.000000
# 1444       Baseline   MS2083  2:2  1.043478  0.500000  28.3  2.057400
# 1452       Baseline   MS2083  2:2  0.960000  1.000000  37.0  1.040843
# ...             ...      ...  ...       ...       ...   ...       ...
# 526423           Y3  MS14472  2:2  1.015994  1.012586  36.2  1.003370
# 526738           Y3  MS14472  2:2  1.000000  1.016929  36.3  1.016922
# 526776           Y3  MS14472  2:2  1.040000  1.000000  37.0  1.039240
# 526835           Y3  MS14472  2:2  1.000000  1.015809  35.8  1.015806
# 526929           Y3  MS14472  2:2  0.213675  1.012972  35.3  4.740460
#
#         chipOrControl
# 276                 1
# 716                 1
# 1332                1
# 1444                1
# 1452                1
# ...               ...
# 526423              1
# 526738              1
# 526776              1
# 526835              1
# 526929              1
#
# [1941 rows x 14 columns]

# %%
false_control
# Out:
#            DP     VD      AF    HIAF  SYMBOL                    loci  \
# 11953   18320    516  0.0282  0.0286  DNMT3A  chr2:25457256_GACGTC/G
# 12213     144      4  0.0278  0.0280  DNMT3A       chr2:25464507_G/A
# 12303      16      2  0.1250  0.1250  DNMT3A       chr2:25468147_A/G
# 12775     408    215  0.5270  0.5179    TET2      chr4:106155751_G/A
# 13759     163      4  0.0245  0.0191    TET2      chr4:106157812_G/A
# ...       ...    ...     ...     ...     ...                     ...
# 536378    179      4  0.0223  0.0227   ASXL1      chr20:31022811_T/C
# 536382   6820   6749  0.9896  0.9962   ASXL1      chr20:31022959_T/C
# 536400    178      4  0.0225  0.0225   ASXL1      chr20:31023305_G/A
# 536482  53257  26575  0.4990  0.4976    LIPI      chr21:15481365_G/T
# 536488     69      2  0.0290  0.0303   U2AF1      chr21:44527564_T/C
#
#        sampleTimePt     MSID BIAS   REFBIAS   VARBIAS  QUAL  ODDRATIO  \
# 11953      Baseline  MS14128  2:2  1.012819  1.015625  36.9  1.002768
# 12213      Baseline  MS14128  2:2  1.028986  1.000000  37.0  1.028790
# 12303      Baseline  MS14128  2:2  1.000000  1.000000  31.0  1.000000
# 12775      Baseline  MS14128  2:2  1.010526  1.067308  34.6  1.056022
# 13759      Baseline  MS14128  2:2  0.987342  1.000000  27.5  1.012740
# ...             ...      ...  ...       ...       ...   ...       ...
# 536378           Y3   MS6625  2:2  1.011494  1.000000  37.0  1.011430
# 536382           Y3   MS6625  2:2  1.000000  1.020054  35.7  1.020054
# 536400           Y3   MS6625  2:2  1.000000  1.000000  37.0  1.000000
# 536482           Y3   MS6625  2:2  1.011299  1.011277  35.5  1.000000
# 536488           Y3   MS6625  2:2  1.030303  1.000000  37.0  1.029860
#
#         chipOrControl
# 11953               0
# 12213               0
# 12303               0
# 12775               0
# 13759               0
# ...               ...
# 536378              0
# 536382              0
# 536400              0
# 536482              0
# 536488              0
#
# [1682 rows x 14 columns]

# %%
print("ACTUAL_CHIP DESCRIPTION")
print(" ")
print(actual_chip.describe())
print(" ")
print("FALSE_CONTROL DESCRIPTION")
print(" ")
print(false_control.describe())
# Out:
# ACTUAL_CHIP DESCRIPTION
#
#                   DP             VD           AF         HIAF      REFBIAS  \
# count    1941.000000    1941.000000  1941.000000  1941.000000  1941.000000
# mean     5730.137043    3782.135497     0.197759     0.199533     1.098606
# std     22055.169437   16979.919135     0.312914     0.314402     3.740221
# min         2.000000       2.000000     0.020000     0.013900     0.000000
# 25%        50.000000       2.000000     0.025000     0.025300     1.000000
# 50%        89.000000       2.000000     0.040800     0.041700     1.000000
# 75%       250.000000       9.000000     0.142900     0.150200     1.030303
# max    324189.000000  319533.000000     1.000000     1.000000   104.666667
#
#            VARBIAS         QUAL      ODDRATIO  chipOrControl
# count  1941.000000  1941.000000   1941.000000         1941.0
# mean      1.386735    35.952550      8.543060            1.0
# std      16.476665     2.157903    324.243488            0.0
# min       0.000000    24.200000      0.000000            1.0
# 25%       1.000000    35.800000      1.000000            1.0
# 50%       1.000000    37.000000      1.011879            1.0
# 75%       1.000000    37.000000      1.040850            1.0
# max     724.500000    37.000000  14285.714286            1.0
#
# FALSE_CONTROL DESCRIPTION
#
#                   DP             VD           AF         HIAF      REFBIAS  \
# count    1682.000000    1682.000000  1682.000000  1682.000000  1682.000000
# mean     5921.252675    3777.563020     0.224228     0.225863     1.097146
# std     21819.591387   14665.861039     0.329946     0.331253     3.352711
# min         2.000000       2.000000     0.020000     0.013500     0.000000
# 25%        49.000000       2.000000     0.026000     0.026300     1.000000
# 50%        86.000000       2.000000     0.040800     0.041700     1.000000
# 75%       194.750000       6.000000     0.333300     0.333300     1.029412
# max    272500.000000  222701.000000     1.000000     1.000000    88.000000
#
#            VARBIAS         QUAL     ODDRATIO  chipOrControl
# count  1682.000000  1682.000000  1682.000000         1682.0
# mean      1.006684    35.906005     1.207318            0.0
# std       0.321588     2.213230     3.638196            0.0
# min       0.000000    22.900000     0.000000            0.0
# 25%       1.000000    35.700000     1.000000            0.0
# 50%       1.000000    37.000000     1.010363            0.0
# 75%       1.000000    37.000000     1.039630            0.0
# max      10.000000    37.000000   130.718954            0.0

# %% [markdown]
# ### WITH THE SECOND DATASET

# %%
df2 = pd.read_csv("chipVariantCalling_run2.tsv", sep = '\t', low_memory = False)
df2.head()
# Out:
#     d.barcode    DP  VD      AF    HIAF IMPACT SYMBOL              loci  \
# 0  4010289633  2036   6  0.0029  0.0044   HIGH   GNB1  chr1:1747193_A/G
# 1  4010289633  2036   6  0.0029  0.0044   HIGH   GNB1  chr1:1747193_A/G
# 2  4010289633  2036   6  0.0029  0.0044   HIGH   GNB1  chr1:1747193_A/G
# 3  4010289633  2036   6  0.0029  0.0044   HIGH   GNB1  chr1:1747193_A/G
# 4  4010289633  2036   6  0.0029  0.0044   HIGH   GNB1  chr1:1747193_A/G
#
#   sampleTimePt gender    MSID BIAS  REFBIAS VARBIAS  QUAL  ODDRATIO  \
# 0     Baseline   Male  MS2083  2:2  940:982     3:3  35.0   1.04467
# 1     Baseline   Male  MS2083  2:2  940:982     3:3  35.0   1.04467
# 2     Baseline   Male  MS2083  2:2  940:982     3:3  35.0   1.04467
# 3     Baseline   Male  MS2083  2:2  940:982     3:3  35.0   1.04467
# 4     Baseline   Male  MS2083  2:2  940:982     3:3  35.0   1.04467
#
#   chipOrControl
# 0          CHIP
# 1          CHIP
# 2          CHIP
# 3          CHIP
# 4          CHIP

# %%
#drop unnecessary columns
df2 = df2[df2.chipOrControl != 'Blank']
df2 = df2[df2.chipOrControl != 'Unknown']
df2 = df2.drop_duplicates()
df2 = df2.dropna(subset=['chipOrControl'])
df2.drop(['d.barcode', 'IMPACT', 'gender'], axis=1, inplace=True)

# %%
df2 = df2.replace({'chipOrControl': {'CHIP': 1, 'Control': 0}})

df2.head()
# Out:
#       DP  VD      AF    HIAF SYMBOL              loci sampleTimePt    MSID  \
# 0   2036   6  0.0029  0.0044   GNB1  chr1:1747193_A/G     Baseline  MS2083
# 5   2036   7  0.0034  0.0035   GNB1  chr1:1747198_G/A     Baseline  MS2083
# 9   2040   5  0.0025  0.0021   GNB1  chr1:1747220_C/T     Baseline  MS2083
# 13  2041   6  0.0029  0.0025   GNB1  chr1:1747238_G/A     Baseline  MS2083
# 17  2037   5  0.0025  0.0028   GNB1  chr1:1747256_T/C     Baseline  MS2083
#
#    BIAS    REFBIAS VARBIAS  QUAL  ODDRATIO  chipOrControl
# 0   2:2    940:982     3:3  35.0   1.04467              1
# 5   2:2  1007:1019     3:4  35.3   1.31745              1
# 9   2:2  1002:1014     2:3  31.8   1.48196              1
# 13  2:2  1008:1025     3:3  32.7   1.01686              1
# 17  2:2   920:1028     2:3  32.2   1.34221              1

# %%
#converting reference bias and variable bias to float types
def ratio_to_int(string):
    a, b = string.split(":")
    if int(b) == 0:
        return 0
    else:
        return int(a) / int(b)

refbias = []
varbias = []

for ratio in df2.REFBIAS.array:
    refbias.append(ratio_to_int(str(ratio))) 

for ratio in df2.VARBIAS.array:
    varbias.append(ratio_to_int(str(ratio))) 
    
refbias = pd.Series(refbias)
varbias = pd.Series(varbias)

df2['REFBIAS'] = refbias.values
df2['VARBIAS'] = varbias.values

# %%
df2
# Out:
#           DP   VD      AF    HIAF SYMBOL                loci sampleTimePt  \
# 0       2036    6  0.0029  0.0044   GNB1    chr1:1747193_A/G     Baseline
# 5       2036    7  0.0034  0.0035   GNB1    chr1:1747198_G/A     Baseline
# 9       2040    5  0.0025  0.0021   GNB1    chr1:1747220_C/T     Baseline
# 13      2041    6  0.0029  0.0025   GNB1    chr1:1747238_G/A     Baseline
# 17      2037    5  0.0025  0.0028   GNB1    chr1:1747256_T/C     Baseline
# ...      ...  ...     ...     ...    ...                 ...          ...
# 693014  4820   16  0.0033  0.0025  BRCC3  chrX:154306961_T/C           Y3
# 693021  4805   13  0.0027  0.0027  BRCC3  chrX:154306969_T/C           Y3
# 693028  4788  133  0.0278  0.0199  BRCC3  chrX:154306974_T/G           Y3
# 693035  4788   14  0.0029  0.0030  BRCC3  chrX:154306976_T/C           Y3
# 693042  4777   17  0.0036  0.0028  BRCC3  chrX:154306989_T/G           Y3
#
#           MSID BIAS   REFBIAS    VARBIAS  QUAL   ODDRATIO  chipOrControl
# 0       MS2083  2:2  0.957230   1.000000  35.0   1.044670              1
# 5       MS2083  2:2  0.988224   0.750000  35.3   1.317450              1
# 9       MS2083  2:2  0.988166   0.666667  31.8   1.481960              1
# 13      MS2083  2:2  0.983415   1.000000  32.7   1.016860              1
# 17      MS2083  2:2  0.894942   0.666667  32.2   1.342210              1
# ...        ...  ...       ...        ...   ...        ...            ...
# 693014  MS6625  2:2  1.019459   0.454545  25.0   2.242460              0
# 693021  MS6625  2:2  1.000839   0.857143  35.0   1.167610              0
# 693028  MS6625  2:2  0.949095  10.083333  27.2  10.620221              0
# 693035  MS6625  2:2  0.998316   1.000000  37.0   1.001683              0
# 693042  MS6625  2:2  0.991416   7.500000  28.1   7.562580              0
#
# [157676 rows x 14 columns]

# %% [markdown]
# Twp different dataframes:
#
# `actual_chip` - contains all the values with `AF`>= 0.02 (by contemporary definition) and are classified as CHIP
#
# `false_control` - contains all the values with `AF`>= 0.02 but are classified as Control

# %%
allele_fq_2 = df2[df2["AF"] < 0.02]
actual_chip2 = allele_fq_2[allele_fq_2["chipOrControl"] == 1]
false_control2 = allele_fq_2[allele_fq_2["chipOrControl"] == 0]
actual_chip2
# Out:
#            DP   VD      AF    HIAF SYMBOL                      loci  \
# 0        2036    6  0.0029  0.0044   GNB1          chr1:1747193_A/G
# 5        2036    7  0.0034  0.0035   GNB1          chr1:1747198_G/A
# 9        2040    5  0.0025  0.0021   GNB1          chr1:1747220_C/T
# 13       2041    6  0.0029  0.0025   GNB1          chr1:1747238_G/A
# 17       2037    5  0.0025  0.0028   GNB1          chr1:1747256_T/C
# ...       ...  ...     ...     ...    ...                       ...
# 679619   5716   16  0.0028  0.0028  BRCC3  chrX:154305536_AGCT/CGCG
# 679626   5694   23  0.0040  0.0042  BRCC3    chrX:154305539_TGT/GGG
# 679633  32479   85  0.0026  0.0017  BRCC3        chrX:154306943_C/A
# 679647  32072  330  0.0103  0.0073  BRCC3        chrX:154306985_A/C
# 679648  32045  485  0.0151  0.0111  BRCC3        chrX:154306989_T/G
#
#        sampleTimePt     MSID BIAS   REFBIAS    VARBIAS  QUAL   ODDRATIO  \
# 0          Baseline   MS2083  2:2  0.957230   1.000000  35.0   1.044670
# 5          Baseline   MS2083  2:2  0.988224   0.750000  35.3   1.317450
# 9          Baseline   MS2083  2:2  0.988166   0.666667  31.8   1.481960
# 13         Baseline   MS2083  2:2  0.983415   1.000000  32.7   1.016860
# 17         Baseline   MS2083  2:2  0.894942   0.666667  32.2   1.342210
# ...             ...      ...  ...       ...        ...   ...        ...
# 679619           Y3  MS14472  2:1  0.838986   0.000000  36.8   0.000000
# 679626           Y3  MS14472  2:1  0.730211   0.000000  36.8   0.000000
# 679633           Y3  MS14472  2:2  1.020416   2.695652  24.2   2.641799
# 679647           Y3  MS14472  2:2  0.967013  18.411765  27.0  19.040366
# 679648           Y3  MS14472  2:2  0.966014  12.857143  28.3  13.313806
#
#         chipOrControl
# 0                   1
# 5                   1
# 9                   1
# 13                  1
# 17                  1
# ...               ...
# 679619              1
# 679626              1
# 679633              1
# 679647              1
# 679648              1
#
# [77396 rows x 14 columns]

# %%
false_control2
# Out:
#           DP  VD      AF    HIAF SYMBOL                  loci sampleTimePt  \
# 14554   5989  15  0.0025  0.0019   GNB1      chr1:1747228_T/C     Baseline
# 14558   5985  19  0.0032  0.0054   GNB1  chr1:1747246_AGT/CGG     Baseline
# 14562   5979  16  0.0027  0.0027   GNB1      chr1:1747256_T/C     Baseline
# 14566   5962  15  0.0025  0.0026   GNB1      chr1:1747279_A/G     Baseline
# 14570    661   3  0.0045  0.0032   NRAS    chr1:115256491_T/C     Baseline
# ...      ...  ..     ...     ...    ...                   ...          ...
# 693007  4818  39  0.0081  0.0062  BRCC3    chrX:154306957_A/T           Y3
# 693014  4820  16  0.0033  0.0025  BRCC3    chrX:154306961_T/C           Y3
# 693021  4805  13  0.0027  0.0027  BRCC3    chrX:154306969_T/C           Y3
# 693035  4788  14  0.0029  0.0030  BRCC3    chrX:154306976_T/C           Y3
# 693042  4777  17  0.0036  0.0028  BRCC3    chrX:154306989_T/G           Y3
#
#            MSID BIAS   REFBIAS   VARBIAS  QUAL  ODDRATIO  chipOrControl
# 14554   MS14128  2:2  0.971268  0.875000  30.1  1.109990              0
# 14558   MS14128  2:1  0.462071  0.000000  34.3  0.000000              0
# 14562   MS14128  2:2  0.882217  1.000000  32.2  1.133478              0
# 14566   MS14128  2:2  0.951736  1.142857  34.5  1.200768              0
# 14570   MS14128  2:2  0.969970  0.500000  28.3  1.938060              0
# ...         ...  ...       ...       ...   ...       ...            ...
# 693007   MS6625  2:2  1.027062  3.875000  26.5  3.771735              0
# 693014   MS6625  2:2  1.019459  0.454545  25.0  2.242460              0
# 693021   MS6625  2:2  1.000839  0.857143  35.0  1.167610              0
# 693035   MS6625  2:2  0.998316  1.000000  37.0  1.001683              0
# 693042   MS6625  2:2  0.991416  7.500000  28.1  7.562580              0
#
# [70952 rows x 14 columns]

# %%
print("ACTUAL_CHIP DESCRIPTION")
print(" ")
print(actual_chip2.describe())
print(" ")
print("FALSE_CONTROL DESCRIPTION")
print(" ")
print(false_control2.describe())
# Out:
# ACTUAL_CHIP DESCRIPTION
#
#                   DP            VD            AF          HIAF       REFBIAS  \
# count   77396.000000  77396.000000  77396.000000  77396.000000  77396.000000
# mean     3151.968073     13.425087      0.004880      0.004696     10.262888
# std      5395.925810     28.312495      0.003185      0.003188    169.152672
# min       101.000000      2.000000      0.002500      0.001500      0.000000
# 25%       756.000000      3.000000      0.002900      0.002800      0.869123
# 50%      1641.000000      6.000000      0.003600      0.003500      0.982071
# 75%      3545.250000     13.000000      0.005400      0.005200      1.027848
# max    216036.000000   1582.000000      0.019900      0.035700  13870.000000
#
#             VARBIAS          QUAL      ODDRATIO  chipOrControl
# count  77396.000000  77396.000000  77396.000000        77396.0
# mean       1.390874     32.327237      1.988175            1.0
# std        2.334504      4.323360      5.406166            0.0
# min        0.000000     22.500000      0.000000            1.0
# 25%        0.555556     28.500000      1.018580            1.0
# 50%        1.000000     33.000000      1.100413            1.0
# 75%        1.000000     37.000000      1.583107            1.0
# max       73.000000     37.000000    571.428571            1.0
#
# FALSE_CONTROL DESCRIPTION
#
#                   DP            VD            AF          HIAF       REFBIAS  \
# count   70952.000000  70952.000000  70952.000000  70952.000000  70952.000000
# mean     2813.046961     11.960353      0.004806      0.004633      9.844935
# std      4535.053280     23.941698      0.003112      0.003127    151.835862
# min       101.000000      2.000000      0.002500      0.001500      0.000000
# 25%       761.000000      3.000000      0.002900      0.002800      0.862430
# 50%      1547.000000      6.000000      0.003600      0.003500      0.981315
# 75%      3154.000000     12.000000      0.005300      0.005100      1.026718
# max    183492.000000   1225.000000      0.019900      0.047600  11491.000000
#
#             VARBIAS          QUAL      ODDRATIO  chipOrControl
# count  70952.000000  70952.000000  70952.000000        70952.0
# mean       1.343319     32.344971      1.907752            0.0
# std        2.197141      4.327461      5.727969            0.0
# min        0.000000     22.500000      0.000000            0.0
# 25%        0.500000     28.600000      1.016977            0.0
# 50%        1.000000     33.000000      1.095062            0.0
# 75%        1.000000     37.000000      1.573602            0.0
# max       38.000000     37.000000    906.330480            0.0
